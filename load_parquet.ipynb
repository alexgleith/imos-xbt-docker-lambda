# %%
import xarray as xr
import pyarrow.parquet as pq

# %%
table = pq.read_table(
    's3://imos-data-lab-optimised/parquet/xbt/',
    columns=["temp", "depth"],
    filters=[('glob_gtspp', '=', 1)]
)

# %%
# Convert to an xarray
ds = xr.Dataset(table.to_pandas())

# %%
ds.plot.scatter(x="temp", y="depth", size=10, hue="temp")

# %%
# Not really helpful...
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.GeoSeries.from_wkt(df.geom.astype(str).values),
    crs="epsg:4326"
).drop(columns=['geom'])

# %%
deep = gdf.query('depth > 1000').query('geometry.x > 156')

# %%
gdf.plot(column='temp', cmap='Reds', marker='o', markersize=1)
# Out:
# <AxesSubplot:>
